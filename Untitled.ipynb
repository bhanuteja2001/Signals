# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns

# %%
freq = np.arange(-12,12,0.01)

# %%
P = []
for i in freq:
    if -11<=i<=-3 or 3<=i<=11:
        P.append(1)
    else:
        P.append(0)

# %% [markdown]
# ## frequency response of the filter

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(freq,P,linewidth=2)
ax.set_xlim(freq.min(), freq.max())
formatter = mticker.ScalarFormatter()
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_major_locator(mticker.FixedLocator(np.arange(freq.min(), freq.max()+1)))
ax.margins(0.5, 0.5)
ax.grid(True, which='both')
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
plt.show()

# %% [markdown]
# ### PSD of white noise

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(freq,np.ones(len(freq)),linewidth=5)
ax.grid(True, which='both')
ax.margins(0.5, 0.5)
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

# %% [markdown]
# ## Snc(f) and Sns(f)

# %%
A = np.arange(-11,11,0.01)
PA = []
for i in A:
    if -4<=i<=4:
        PA.append(1)
    else:
        PA.append(0)

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(A,PA,linewidth=5)
ax.grid(True, which='both')
ax.margins(0.5, 0.5)
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')

# %% [markdown]
# ## Sn(f)
